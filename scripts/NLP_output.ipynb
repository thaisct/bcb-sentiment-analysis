# %%
import pandas as pd
import matplotlib as plt
import plotly.express as px 
import os
os.chdir("C:\\Users\\Thais\\Documents\\Python\\bcb-sentiment-analysis")

# %%
df_original = pd.read_pickle(".\\data\\minutes\\minutes_scores_original.pkl", compression='infer', storage_options=None).set_index('date')
df_new = pd.read_pickle(".\\data\\minutes\\minutes_scores_finbert_20230430.pkl", compression='infer', storage_options=None).set_index('date')

# %%
df_original['score'][8:].rolling(window=6).mean().plot(figsize = [20, 15])
df_new['score'][8:].rolling(window=6).mean().plot(figsize = [20, 15])

# %%
s1 = pd.DataFrame(df_original['score'][8:].rolling(window=4).mean())
s1.columns = ['score_o']
s2 = pd.DataFrame(df_new['score'][8:].rolling(window=4).mean())
ls_df = [s1,s2]
df = pd.concat(ls_df)

# %%
fig = px.line(df)
fig.show()

# %% [markdown]
# Pegar mais trechos de atas dos seguintes períodos:
#
# - Jul 2007  - Jun 2009
# - Atas de 2014 (Crise Hídrica)
# - Atas de 2015 - 2016 (Crise Política) - Impeachment Ago 2016
# - Maio 2017 - JBS
# - Maio 2018 - grve dos caminhoneiros
# - Atas da pandemia
