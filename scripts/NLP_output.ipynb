# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import plotly.express as px 
import plotly.graph_objects as go
import os
os.chdir("C:\\Users\\Thais\\Documents\\Python\\bcb-sentiment-analysis")

# %%
def flatten(l):
    return [item for sublist in l for item in sublist]

# %%
df_finbert = pd.DataFrame(pd.read_pickle(".\\data\\minutes\\minutes_scores_original.pkl", compression='infer', storage_options=None).set_index('date')['score'][8:])
df_finbert_s = pd.DataFrame(pd.read_pickle(".\\data\\minutes\\minutes_scores_original.pkl", compression='infer', storage_options=None).set_index('date')['score'][8:].rolling(window=4).mean())

df_uncased = pd.DataFrame(pd.read_pickle(".\\data\\minutes\\minutes_scores_uncased.pkl", compression='infer', storage_options=None).set_index('date')['score'][8:])
df_uncased_s = pd.DataFrame(pd.read_pickle(".\\data\\minutes\\minutes_scores_uncased.pkl", compression='infer', storage_options=None).set_index('date')['score'][8:].rolling(window=4).mean())

df_f1 = pd.DataFrame(pd.read_pickle(".\\data\\minutes\\minutes_scores_finbert_20230423.pkl", compression='infer', storage_options=None).set_index('date')['score'][8:])
df_f1_s = pd.DataFrame(pd.read_pickle(".\\data\\minutes\\minutes_scores_finbert_20230423.pkl", compression='infer', storage_options=None).set_index('date')['score'][8:].rolling(window=4).mean())

df_f2 = pd.DataFrame(pd.read_pickle(".\\data\\minutes\\minutes_scores_finbert_20230430.pkl", compression='infer', storage_options=None).set_index('date')['score'][8:])
df_f2_s = pd.DataFrame(pd.read_pickle(".\\data\\minutes\\minutes_scores_finbert_20230430.pkl", compression='infer', storage_options=None).set_index('date')['score'][8:].rolling(window=4).mean())

df_f3 = pd.DataFrame(pd.read_pickle(".\\data\\minutes\\minutes_scores_finbert_20230608.pkl", compression='infer', storage_options=None).set_index('date')['score'][8:])
df_f3_s = pd.DataFrame(pd.read_pickle(".\\data\\minutes\\minutes_scores_finbert_20230608.pkl", compression='infer', storage_options=None).set_index('date')['score'][8:].rolling(window=4).mean())

df_u1 = pd.DataFrame(pd.read_pickle(".\\data\\minutes\\minutes_scores_uncased_20230423.pkl", compression='infer', storage_options=None).set_index('date')['score'][8:])
df_u1_s = pd.DataFrame(pd.read_pickle(".\\data\\minutes\\minutes_scores_uncased_20230423.pkl", compression='infer', storage_options=None).set_index('date')['score'][8:].rolling(window=4).mean())

df_u2 = pd.DataFrame(pd.read_pickle(".\\data\\minutes\\minutes_scores_uncased_20230430.pkl", compression='infer', storage_options=None).set_index('date')['score'][8:])
df_u2_s = pd.DataFrame(pd.read_pickle(".\\data\\minutes\\minutes_scores_uncased_20230430.pkl", compression='infer', storage_options=None).set_index('date')['score'][8:].rolling(window=4).mean())

df_u3 = pd.DataFrame(pd.read_pickle(".\\data\\minutes\\minutes_scores_uncased_20230608.pkl", compression='infer', storage_options=None).set_index('date')['score'][8:])
df_u3_s = pd.DataFrame(pd.read_pickle(".\\data\\minutes\\minutes_scores_uncased_20230608.pkl", compression='infer', storage_options=None).set_index('date')['score'][8:].rolling(window=4).mean())

# %% [markdown]
# # Fig 1

# %%
fig = go.Figure(layout = go.Layout(width=1400, height=700))
fig.add_trace(go.Scatter(x = list(df_finbert.index), y= flatten(np.ndarray.tolist(df_finbert.values)),
                         name="Série Original"))
fig.add_trace(go.Scatter(x = list(df_finbert_s.index), y= flatten(np.ndarray.tolist(df_finbert_s.values)),
                         name="Média Móvel de 3 reuniões"))
fig.update_layout(
    title=dict(text = "Sentimento das Atas (FinBERT)", font=dict(size=40)),
    xaxis_title="Datas de Publicação",
    yaxis_title="Sentimento",
    legend_title="",
        legend=dict(
        yanchor="top",
        y=0.99,
        xanchor="left",
        x=0.8,
        bgcolor = "rgba(0,0,0,0)"
        ),
    font = dict(size = 15)
    )
fig.show()

# %% [markdown]
# # Fig 2

# %%
fig = go.Figure(layout = go.Layout(width=1400, height=700))
fig.add_trace(go.Scatter(x = list(df_finbert_s.index), y= flatten(np.ndarray.tolist(df_finbert_s.values)),
                         name="Média Móvel da Série Original (FinBERT)", line = dict(color = 'blue')))
fig.add_trace(go.Scatter(x = list(df_f2_s.index), y= flatten(np.ndarray.tolist(df_f2_s.values)),
                         name="Média Móvel (FinBERT refinado)", line = dict(color = 'blue', dash = 'dash')))
fig.add_trace(go.Scatter(x = list(df_uncased_s.index), y= flatten(np.ndarray.tolist(df_uncased_s.values)),
                         name="Média Móvel da Série Original (BERT uncased)", line = dict(color = 'red')))
fig.add_trace(go.Scatter(x = list(df_u1_s.index), y= flatten(np.ndarray.tolist(df_u1_s.values)),
                         name="Média Móvel (BERT uncased refinado)", line = dict(color = 'red', dash = 'dash')))

fig.update_layout(
    title=dict(text = "Sentimento das Atas", font=dict(size=40)),
    xaxis_title="Datas de Publicação",
    yaxis_title="Sentimento",
    legend_title="",
        legend=dict(
        yanchor="top",
        y=0.99,
        xanchor="left",
        x=0.13,
        bgcolor = "rgba(0,0,0,0)"
        ),
    font = dict(size = 15)
    )

periods = [
    dict(start='2007-07-01', end='2009-06-30', mid_x = '2008-07-01', mid_y = 18, name = 'GFC' ,color='orange'),  
    dict(start='2015-11-01', end='2016-11-30', mid_x = '2016-05-30', mid_y = 18,name = 'Crise Política', color='orange'),
    dict(start='2018-05-01', end='2018-06-30', mid_x = '2018-05-31', mid_y = 25,name = 'Greve dos Caminhoneiros', color='orange'),
    dict(start='2020-04-01', end='2021-10-31', mid_x = '2021-01-15', mid_y = 18,name = 'Pandemia', color='orange'),  
]

# Add the rectangles to the layout
for period in periods:
    fig.add_shape(
        type="rect",
        xref="x",
        yref="paper",
        x0=period['start'],
        y0=0,
        x1=period['end'],
        y1=1,
        fillcolor=period['color'],
        opacity=0.5,
        layer="below",
        line_width=0,
    )
        # Add the annotation for the period name
    fig.add_annotation(
        x=period['mid_x'],
        y=period['mid_y'],
        text=period['name'],
        showarrow=False,
        font=dict(size=12, color='black'),
    )
fig.show()

# %% [markdown]
# Pegar mais trechos de atas dos seguintes períodos:
#
# - Jul 2007  - Jun 2009
# - Atas de 2014 (Crise Hídrica)
# - Atas de 2015 - 2016 (Crise Política) - Impeachment Ago 2016
# - Maio 2017 - JBS
# - Maio 2018 - grve dos caminhoneiros
# - Atas da pandemia
