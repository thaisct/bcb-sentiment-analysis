# %%
import pandas as pd
import matplotlib as plt
import os
os.chdir("C:\\Users\\Thais\\Documents\\Python\\bcb-sentiment-analysis")

# %%
df_original = pd.read_pickle(".\\data\\minutes\\minutes_scores_original.pkl", compression='infer', storage_options=None).set_index('date')
df_new = pd.read_pickle(".\\data\\minutes\\minutes_scores.pkl", compression='infer', storage_options=None).set_index('date')

# %%
df_original['score'][8:].rolling(window=3).mean().plot(figsize = [20, 15])
df_new['score'][8:].rolling(window=3).mean().plot(figsize = [20, 15])
# Out:
# <AxesSubplot:xlabel='date'>
